# %% [markdown]
# #### This notebook was inspired from [medium](https://medium.com/)###and [here](https://www.kaggle.com/code/ammarnassanalhajali/layout-parser-model-training) ##and [here](https://www.kaggle.com/code/salmankhondker/starter-notebook-dl-sprint-2-0)##and [here](https://www.kaggle.com/code/ataullhasaim/mws-dl-enigma-1-0-starter-notebook)

# %%
#install detectron2
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-b_p8byg8
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-b_p8byg8
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 3ff5dd1cff4417af07097064813c9f28d7461d3c
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (9.5.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (3.7.4)
# Collecting pycocotools>=2.0.2 (from detectron2==0.6)
#   Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: termcolor>=1.1 in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (2.4.0)
# Collecting yacs>=0.1.8 (from detectron2==0.6)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (4.66.1)
# Requirement already satisfied: tensorboard in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (2.15.1)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.5 MB/s eta 0:00:00
# done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf<2.4,>=2.1 (from detectron2==0.6)
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.8 MB/s eta 0:00:00
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 9.4 MB/s eta 0:00:00
# Collecting black (from detectron2==0.6)
#   Downloading black-24.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from detectron2==0.6) (21.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.24.4)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.1)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2==0.6)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 7.1 MB/s eta 0:00:00
# done
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2==0.6)
#   Downloading portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from black->detectron2==0.6) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/conda/lib/python3.10/site-packages (from black->detectron2==0.6) (1.0.0)
# Collecting packaging (from detectron2==0.6)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2==0.6)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /opt/conda/lib/python3.10/site-packages (from black->detectron2==0.6) (4.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from black->detectron2==0.6) (4.9.0)
# Requirement already satisfied: absl-py>=0.4 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.51.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (3.5.2)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (2.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (69.0.3)
# Requirement already satisfied: six>1.9 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Downloading pycocotools-2.0.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.2/426.2 kB 19.2 MB/s eta 0:00:00
# Downloading black-24.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 56.7 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 3.0 MB/s eta 0:00:00
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
# done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=1261535 sha256=ef3e2b868076cd824fc0c7c68e2852e8ec2750870ae55ee85007a8d6877503ee
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c16y7l12/wheels/47/e5/15/94c80df2ba85500c5d76599cc307c0a7079d0e221bb6fc4375
# done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61400 sha256=641b42879c8a825f930b68f258b392882195f7392781859630050bf4e04acb2e
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
# done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=7feff2bdc1b91b019f7fa6d8e23e159ddd4ba0887f451e9e3a3403bd4ef22f85
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, packaging, omegaconf, iopath, hydra-core, black, pycocotools, fvcore, detectron2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.3.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.1.0 which is incompatible.
# cuml 23.8.0 requires distributed==2023.7.1, but you have distributed 2024.1.0 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2024.1.0 which is incompatible.
# dask-cuda 23.8.0 requires distributed==2023.7.1, but you have distributed 2024.1.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2024.1.0 which is incompatible.
# dask-cudf 23.8.0 requires distributed==2023.7.1, but you have distributed 2024.1.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# google-cloud-bigquery 2.34.4 requires packaging<22.0dev,>=14.3, but you have packaging 23.2 which is incompatible.
# jupyterlab 4.0.11 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.2 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.8.1 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2024.1.0 which is incompatible.
# raft-dask 23.8.0 requires distributed==2023.7.1, but you have distributed 2024.1.0 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# Successfully installed antlr4-python3-runtime-4.9.3 black-24.1.1 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 omegaconf-2.3.0 packaging-23.2 pathspec-0.12.1 portalocker-2.8.2 pycocotools-2.0.7 yacs-0.1.8

# %%
# detectron2 imports
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()
from detectron2 import model_zoo
from detectron2.engine import DefaultTrainer
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.structures import BoxMode
from detectron2.data import DatasetCatalog, MetadataCatalog
from detectron2.evaluation import COCOEvaluator, inference_on_dataset, LVISEvaluator
from detectron2.data import build_detection_test_loader
from detectron2.utils.visualizer import ColorMode

# other libs (other necessary imports in Colab file to make the list shorter here)

import torch, torchvision
import torchvision.transforms as transforms
from pathlib import Path
import os
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm
import pandas as pd
import cv2
from pathlib import Path
import os

# %%
#coco Data create and register
def create_data_pairs(input_path, detectron_img_path, detectron_annot_path, dir_type = 'train'):

    img_paths = Path(input_path +'/images/train/').glob('*.jpg')

    pairs = []
    for img_path in img_paths:

        file_name_tmp = str(img_path).split('/')[-1].split('.')
        file_name_tmp.pop(-1)
        file_name = '.'.join((file_name_tmp))

        label_path = Path(input_path + '/labels/train/' + file_name + '.txt')

        if label_path.is_file():

            line_img = detectron_img_path + '/images/train/'+ file_name + '.jpg'
            line_annot = detectron_annot_path+'/labels/train/' + file_name + '.txt'
            pairs.append([line_img, line_annot])

    return pairs

input_path = '/kaggle/input/dl-enigma-10-sust-cse-carnival-2024/dlenigma1/BadODD'

detectron_img_path = '/kaggle/input/dl-enigma-10-sust-cse-carnival-2024/dlenigma1/BadODD'
detectron_annot_path = '/kaggle/input/dl-enigma-10-sust-cse-carnival-2024/dlenigma1/BadODD'

train = create_data_pairs(input_path, detectron_img_path, detectron_annot_path, 'train')
val = create_data_pairs(input_path, detectron_img_path, detectron_annot_path, 'valid')

# %%
def create_coco_format(data_pairs):
    
    data_list = []

    for i, path in enumerate(data_pairs):
        
        filename = path[0]

        img_h, img_w = cv2.imread(filename).shape[:2]

        img_item = {}
        img_item['file_name'] = filename
        img_item['image_id'] = i
        img_item['height']= img_h
        img_item['width']= img_w

        #print(str(i), filename)


        annotations = []
        with open(path[1]) as annot_file:
            lines = annot_file.readlines()
            for line in lines:
                if line[-1]=="\n":
                  box = line[:-1].split(' ')
                else:
                  box = line.split(' ')

                class_id = box[0]
                x_c = float(box[1])
                y_c = float(box[2])
                width = float(box[3])
                height = float(box[4])

                x1 = (x_c - (width/2)) * img_w
                y1 = (y_c - (height/2)) * img_h
                x2 = (x_c + (width/2)) * img_w
                y2 = (y_c + (height/2)) * img_h

                annotation = {
                    "bbox": list(map(float,[x1, y1, x2, y2])),
                    "bbox_mode": BoxMode.XYXY_ABS,
                    "category_id": int(class_id),
                    "iscrowd": 0
                }
                annotations.append(annotation)
            img_item["annotations"] = annotations
        data_list.append(img_item)
    return data_list 

train_list = create_coco_format(train)
val_list = create_coco_format(val)

# %%
for catalog_name, file_annots in [("train", train_list), ("val", val_list)]:
    DatasetCatalog.register(catalog_name, lambda file_annots = file_annots: file_annots)
    MetadataCatalog.get(catalog_name).set(thing_classes=['auto_rickshaw', 'bicycle', 'bus', 'car', 'cart_vehicle', 'construction_vehicle', 'motorbike', 'person', 'priority_vehicle', 'three_wheeler', 'train', 'truck', 'wheelchair'])

metadata = MetadataCatalog.get("train")

# %%
#training
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("train",)
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.DEVICE = 'cuda' # cuda
cfg.MODEL.WEIGHTS = "detectron2://COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl"
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.CHECKPOINT_PERIOD = 500
cfg.SOLVER.WARMUP_ITERS = 500
cfg.SOLVER.GAMMA = 0.05
cfg.SOLVER.BASE_LR = 0.0005
cfg.SOLVER.MAX_ITER = 25000 # (train_size / batch_size) * 100
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 256 # 512
cfg.MODEL.ROI_HEADS.NUM_CLASSES = len(MetadataCatalog.get("train").thing_classes)
cfg.SOLVER.STEPS = (20500, )

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)

import time as t
s1 = t.time()
try:
  trainer.train()
except:
  None
s2 = t.time()
print(s2-s1)
# Out:
# [02/09 08:44:23 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=14, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=52, bias=True)
#     )
#   )
# )
# [02/09 08:44:23 d2.data.build]: Removed 0 images with no usable annotations. 5896 images left.
# [02/09 08:44:23 d2.data.build]: Distribution of instances among all 13 categories:
# |   category    | #instances   |   category   | #instances   |   category    | #instances   |
# |:-------------:|:-------------|:------------:|:-------------|:-------------:|:-------------|
# | auto_rickshaw | 10614        |   bicycle    | 673          |      bus      | 1885         |
# |      car      | 3785         | cart_vehicle | 141          | constructio.. | 23           |
# |   motorbike   | 3749         |    person    | 18010        | priority_ve.. | 229          |
# | three_wheeler | 5710         |    train     | 1            |     truck     | 2296         |
# |  wheelchair   | 2            |              |              |               |              |
# |     total     | 47118        |              |              |               |              |
# [02/09 08:44:23 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [02/09 08:44:23 d2.data.build]: Using training sampler TrainingSampler
# [02/09 08:44:23 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [02/09 08:44:23 d2.data.common]: Serializing 5896 elements to byte tensors and concatenating them all ...
# [02/09 08:44:23 d2.data.common]: Serialized dataset takes 4.11 MiB
# [02/09 08:44:23 d2.data.build]: Making batched data loader with batch_size=2
# [02/09 08:44:23 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from detectron2://COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl ...
# model_final_280758.pkl: 167MB [00:00, 244MB/s]
# [02/09 08:44:24 d2.engine.train_loop]: Starting training from iteration 0
# /opt/conda/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /usr/local/src/pytorch/aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [02/09 08:44:33 d2.utils.events]:  eta: 1:57:43  iter: 19  total_loss: 3.46  loss_cls: 2.639  loss_box_reg: 0.7318  loss_rpn_cls: 0.02646  loss_rpn_loc: 0.04518    time: 0.2811  last_time: 0.2700  data_time: 0.0152  last_data_time: 0.0055   lr: 1.9481e-05  max_mem: 2550M
# 2024-02-09 08:44:35.414230: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-09 08:44:35.414327: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-09 08:44:35.540013: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [02/09 08:44:49 d2.utils.events]:  eta: 1:58:08  iter: 39  total_loss: 3.156  loss_cls: 2.338  loss_box_reg: 0.7997  loss_rpn_cls: 0.0356  loss_rpn_loc: 0.05261    time: 0.2834  last_time: 0.2837  data_time: 0.0058  last_data_time: 0.0061   lr: 3.9461e-05  max_mem: 2550M
# [02/09 08:44:55 d2.utils.events]:  eta: 1:57:41  iter: 59  total_loss: 2.623  loss_cls: 1.687  loss_box_reg: 0.8435  loss_rpn_cls: 0.02722  loss_rpn_loc: 0.04879    time: 0.2793  last_time: 0.2759  data_time: 0.0060  last_data_time: 0.0062   lr: 5.9441e-05  max_mem: 2550M
# [02/09 08:45:00 d2.utils.events]:  eta: 1:57:25  iter: 79  total_loss: 1.722  loss_cls: 0.9551  loss_box_reg: 0.6468  loss_rpn_cls: 0.02988  loss_rpn_loc: 0.05152    time: 0.2788  last_time: 0.2366  data_time: 0.0058  last_data_time: 0.0058   lr: 7.9421e-05  max_mem: 2550M
# [02/09 08:45:06 d2.utils.events]:  eta: 1:57:27  iter: 99  total_loss: 1.852  loss_cls: 0.9466  loss_box_reg: 0.8002  loss_rpn_cls: 0.02922  loss_rpn_loc: 0.04122    time: 0.2783  last_time: 0.2204  data_time: 0.0062  last_data_time: 0.0060   lr: 9.9401e-05  max_mem: 2550M
# [02/09 08:45:11 d2.utils.events]:  eta: 1:57:08  iter: 119  total_loss: 1.869  loss_cls: 0.9282  loss_box_reg: 0.8317  loss_rpn_cls: 0.03237  loss_rpn_loc: 0.0602    time: 0.2762  last_time: 0.2229  data_time: 0.0056  last_data_time: 0.0067   lr: 0.00011938  max_mem: 2550M
# [02/09 08:45:16 d2.utils.events]:  eta: 1:56:58  iter: 139  total_loss: 1.77  loss_cls: 0.8438  loss_box_reg: 0.8352  loss_rpn_cls: 0.0211  loss_rpn_loc: 0.06291    time: 0.2755  last_time: 0.2940  data_time: 0.0059  last_data_time: 0.0058   lr: 0.00013936  max_mem: 2550M
# [02/09 08:45:22 d2.utils.events]:  eta: 1:56:56  iter: 159  total_loss: 1.777  loss_cls: 0.8227  loss_box_reg: 0.8649  loss_rpn_cls: 0.02339  loss_rpn_loc: 0.06094    time: 0.2754  last_time: 0.2752  data_time: 0.0067  last_data_time: 0.0050   lr: 0.00015934  max_mem: 2551M
# [02/09 08:45:27 d2.utils.events]:  eta: 1:56:54  iter: 179  total_loss: 1.655  loss_cls: 0.7569  loss_box_reg: 0.8116  loss_rpn_cls: 0.02332  loss_rpn_loc: 0.05325    time: 0.2757  last_time: 0.2856  data_time: 0.0059  last_data_time: 0.0071   lr: 0.00017932  max_mem: 2551M
# [02/09 08:45:33 d2.utils.events]:  eta: 1:56:51  iter: 199  total_loss: 1.601  loss_cls: 0.6963  loss_box_reg: 0.8067  loss_rpn_cls: 0.01944  loss_rpn_loc: 0.05583    time: 0.2755  last_time: 0.2852  data_time: 0.0059  last_data_time: 0.0059   lr: 0.0001993  max_mem: 2551M
# [02/09 08:45:38 d2.utils.events]:  eta: 1:56:45  iter: 219  total_loss: 1.56  loss_cls: 0.6476  loss_box_reg: 0.8234  loss_rpn_cls: 0.02926  loss_rpn_loc: 0.05667    time: 0.2751  last_time: 0.2847  data_time: 0.0059  last_data_time: 0.0059   lr: 0.00021928  max_mem: 2551M
# [02/09 08:45:44 d2.utils.events]:  eta: 1:56:34  iter: 239  total_loss: 1.471  loss_cls: 0.6144  loss_box_reg: 0.7922  loss_rpn_cls: 0.02045  loss_rpn_loc: 0.03428    time: 0.2746  last_time: 0.2823  data_time: 0.0058  last_data_time: 0.0061   lr: 0.00023926  max_mem: 2551M
# [02/09 08:45:49 d2.utils.events]:  eta: 1:56:31  iter: 259  total_loss: 1.463  loss_cls: 0.5744  loss_box_reg: 0.7705  loss_rpn_cls: 0.0309  loss_rpn_loc: 0.05737    time: 0.2746  last_time: 0.2557  data_time: 0.0063  last_data_time: 0.0064   lr: 0.00025924  max_mem: 2551M
# [02/09 08:45:55 d2.utils.events]:  eta: 1:56:20  iter: 279  total_loss: 1.2  loss_cls: 0.463  loss_box_reg: 0.6407  loss_rpn_cls: 0.02087  loss_rpn_loc: 0.03984    time: 0.2743  last_time: 0.2845  data_time: 0.0056  last_data_time: 0.0056   lr: 0.00027922  max_mem: 2551M
# [02/09 08:46:00 d2.utils.events]:  eta: 1:56:13  iter: 299  total_loss: 1.303  loss_cls: 0.4884  loss_box_reg: 0.7343  loss_rpn_cls: 0.02078  loss_rpn_loc: 0.04201    time: 0.2745  last_time: 0.2868  data_time: 0.0057  last_data_time: 0.0057   lr: 0.0002992  max_mem: 2551M
# [02/09 08:46:06 d2.utils.events]:  eta: 1:56:04  iter: 319  total_loss: 1.278  loss_cls: 0.4589  loss_box_reg: 0.6775  loss_rpn_cls: 0.01896  loss_rpn_loc: 0.05235    time: 0.2743  last_time: 0.2690  data_time: 0.0056  last_data_time: 0.0036   lr: 0.00031918  max_mem: 2551M
# [02/09 08:46:11 d2.utils.events]:  eta: 1:55:59  iter: 339  total_loss: 1.259  loss_cls: 0.452  loss_box_reg: 0.6398  loss_rpn_cls: 0.02046  loss_rpn_loc: 0.05386    time: 0.2744  last_time: 0.2733  data_time: 0.0059  last_data_time: 0.0061   lr: 0.00033916  max_mem: 2551M
# [02/09 08:46:17 d2.utils.events]:  eta: 1:55:53  iter: 359  total_loss: 1.162  loss_cls: 0.4197  loss_box_reg: 0.6045  loss_rpn_cls: 0.02174  loss_rpn_loc: 0.0436    time: 0.2744  last_time: 0.2778  data_time: 0.0061  last_data_time: 0.0076   lr: 0.00035914  max_mem: 2551M
# [02/09 08:46:22 d2.utils.events]:  eta: 1:55:45  iter: 379  total_loss: 1.224  loss_cls: 0.4909  loss_box_reg: 0.6447  loss_rpn_cls: 0.0319  loss_rpn_loc: 0.05201    time: 0.2742  last_time: 0.2830  data_time: 0.0060  last_data_time: 0.0059   lr: 0.00037912  max_mem: 2551M
# [02/09 08:46:28 d2.utils.events]:  eta: 1:55:40  iter: 399  total_loss: 1.083  loss_cls: 0.4464  loss_box_reg: 0.549  loss_rpn_cls: 0.02433  loss_rpn_loc: 0.05175    time: 0.2740  last_time: 0.2840  data_time: 0.0058  last_data_time: 0.0048   lr: 0.0003991  max_mem: 2551M
# [02/09 08:46:33 d2.utils.events]:  eta: 1:55:35  iter: 419  total_loss: 1.032  loss_cls: 0.4134  loss_box_reg: 0.5178  loss_rpn_cls: 0.00974  loss_rpn_loc: 0.03459    time: 0.2741  last_time: 0.2792  data_time: 0.0059  last_data_time: 0.0056   lr: 0.00041908  max_mem: 2551M
# [02/09 08:46:38 d2.utils.events]:  eta: 1:55:22  iter: 439  total_loss: 1.187  loss_cls: 0.4996  loss_box_reg: 0.5688  loss_rpn_cls: 0.01831  loss_rpn_loc: 0.05679    time: 0.2736  last_time: 0.2811  data_time: 0.0054  last_data_time: 0.0051   lr: 0.00043906  max_mem: 2551M
# [02/09 08:46:44 d2.utils.events]:  eta: 1:55:11  iter: 459  total_loss: 1.007  loss_cls: 0.4375  loss_box_reg: 0.501  loss_rpn_cls: 0.01894  loss_rpn_loc: 0.05392    time: 0.2734  last_time: 0.2827  data_time: 0.0054  last_data_time: 0.0041   lr: 0.00045904  max_mem: 2551M
# [02/09 08:46:49 d2.utils.events]:  eta: 1:55:09  iter: 479  total_loss: 1.046  loss_cls: 0.4432  loss_box_reg: 0.5444  loss_rpn_cls: 0.02075  loss_rpn_loc: 0.04163    time: 0.2735  last_time: 0.2857  data_time: 0.0054  last_data_time: 0.0052   lr: 0.00047902  max_mem: 2551M
# [02/09 08:46:55 d2.utils.events]:  eta: 1:55:04  iter: 499  total_loss: 1.036  loss_cls: 0.381  loss_box_reg: 0.5101  loss_rpn_cls: 0.01999  loss_rpn_loc: 0.06708    time: 0.2736  last_time: 0.2467  data_time: 0.0057  last_data_time: 0.0057   lr: 0.000499  max_mem: 2551M
# [02/09 08:47:01 d2.utils.events]:  eta: 1:54:50  iter: 519  total_loss: 1.256  loss_cls: 0.5178  loss_box_reg: 0.551  loss_rpn_cls: 0.04251  loss_rpn_loc: 0.05036    time: 0.2734  last_time: 0.2842  data_time: 0.0062  last_data_time: 0.0054   lr: 0.0005  max_mem: 2551M
# [02/09 08:47:06 d2.utils.events]:  eta: 1:54:44  iter: 539  total_loss: 1.073  loss_cls: 0.4067  loss_box_reg: 0.5322  loss_rpn_cls: 0.02604  loss_rpn_loc: 0.07568    time: 0.2733  last_time: 0.2867  data_time: 0.0057  last_data_time: 0.0058   lr: 0.0005  max_mem: 2551M
# [02/09 08:47:12 d2.utils.events]:  eta: 1:54:39  iter: 559  total_loss: 0.7318  loss_cls: 0.3231  loss_box_reg: 0.379  loss_rpn_cls: 0.01404  loss_rpn_loc: 0.03172    time: 0.2733  last_time: 0.2957  data_time: 0.0058  last_data_time: 0.0041   lr: 0.0005  max_mem: 2551M
# [02/09 08:47:17 d2.utils.events]:  eta: 1:54:42  iter: 579  total_loss: 0.9866  loss_cls: 0.3962  loss_box_reg: 0.511  loss_rpn_cls: 0.01701  loss_rpn_loc: 0.05128    time: 0.2734  last_time: 0.2471  data_time: 0.0058  last_data_time: 0.0054   lr: 0.0005  max_mem: 2551M
# [02/09 08:47:23 d2.utils.events]:  eta: 1:54:37  iter: 599  total_loss: 0.9346  loss_cls: 0.3963  loss_box_reg: 0.4645  loss_rpn_cls: 0.01748  loss_rpn_loc: 0.06765    time: 0.2734  last_time: 0.2960  data_time: 0.0055  last_data_time: 0.0065   lr: 0.0005  max_mem: 2551M
# [02/09 08:47:28 d2.utils.events]:  eta: 1:54:31  iter: 619  total_loss: 0.946  loss_cls: 0.3851  loss_box_reg: 0.478  loss_rpn_cls: 0.01853  loss_rpn_loc: 0.04266    time: 0.2736  last_time: 0.2771  data_time: 0.0061  last_data_time: 0.0033   lr: 0.0005  max_mem: 2551M
# [02/09 08:47:35 d2.utils.events]:  eta: 1:54:26  iter: 639  total_loss: 0.9919  loss_cls: 0.4116  loss_box_reg: 0.4801  loss_rpn_cls: 0.02266  loss_rpn_loc: 0.05224    time: 0.2737  last_time: 0.2909  data_time: 0.0057  last_data_time: 0.0062   lr: 0.0005  max_mem: 2551M
# [02/09 08:47:41 d2.utils.events]:  eta: 1:54:18  iter: 659  total_loss: 0.9262  loss_cls: 0.3606  loss_box_reg: 0.478  loss_rpn_cls: 0.02496  loss_rpn_loc: 0.04746    time: 0.2736  last_time: 0.2853  data_time: 0.0053  last_data_time: 0.0056   lr: 0.0005  max_mem: 2551M
# [02/09 08:47:46 d2.utils.events]:  eta: 1:54:04  iter: 679  total_loss: 0.9393  loss_cls: 0.3674  loss_box_reg: 0.4363  loss_rpn_cls: 0.01755  loss_rpn_loc: 0.03778    time: 0.2735  last_time: 0.2412  data_time: 0.0059  last_data_time: 0.0062   lr: 0.0005  max_mem: 2551M
# [02/09 08:47:51 d2.utils.events]:  eta: 1:53:58  iter: 699  total_loss: 0.7638  loss_cls: 0.3058  loss_box_reg: 0.3751  loss_rpn_cls: 0.01382  loss_rpn_loc: 0.04493    time: 0.2735  last_time: 0.2842  data_time: 0.0057  last_data_time: 0.0058   lr: 0.0005  max_mem: 2551M
# [02/09 08:47:57 d2.utils.events]:  eta: 1:53:52  iter: 719  total_loss: 0.7771  loss_cls: 0.3292  loss_box_reg: 0.4244  loss_rpn_cls: 0.01796  loss_rpn_loc: 0.03859    time: 0.2734  last_time: 0.2833  data_time: 0.0058  last_data_time: 0.0050   lr: 0.0005  max_mem: 2551M
# [02/09 08:48:02 d2.utils.events]:  eta: 1:53:47  iter: 739  total_loss: 0.9926  loss_cls: 0.4043  loss_box_reg: 0.4835  loss_rpn_cls: 0.01803  loss_rpn_loc: 0.06609    time: 0.2735  last_time: 0.2748  data_time: 0.0056  last_data_time: 0.0051   lr: 0.0005  max_mem: 2551M
# [02/09 08:48:08 d2.utils.events]:  eta: 1:53:41  iter: 759  total_loss: 0.8456  loss_cls: 0.339  loss_box_reg: 0.4005  loss_rpn_cls: 0.01265  loss_rpn_loc: 0.04308    time: 0.2733  last_time: 0.2799  data_time: 0.0059  last_data_time: 0.0066   lr: 0.0005  max_mem: 2551M
# [02/09 08:48:13 d2.utils.events]:  eta: 1:53:36  iter: 779  total_loss: 0.9347  loss_cls: 0.3528  loss_box_reg: 0.4731  loss_rpn_cls: 0.01531  loss_rpn_loc: 0.05147    time: 0.2732  last_time: 0.2796  data_time: 0.0061  last_data_time: 0.0064   lr: 0.0005  max_mem: 2551M
# [02/09 08:48:19 d2.utils.events]:  eta: 1:53:30  iter: 799  total_loss: 0.8868  loss_cls: 0.3675  loss_box_reg: 0.4646  loss_rpn_cls: 0.01544  loss_rpn_loc: 0.0367    time: 0.2732  last_time: 0.2845  data_time: 0.0065  last_data_time: 0.0063   lr: 0.0005  max_mem: 2551M
# [02/09 08:48:24 d2.utils.events]:  eta: 1:53:25  iter: 819  total_loss: 0.9834  loss_cls: 0.3619  loss_box_reg: 0.5424  loss_rpn_cls: 0.02118  loss_rpn_loc: 0.06056    time: 0.2734  last_time: 0.2839  data_time: 0.0062  last_data_time: 0.0057   lr: 0.0005  max_mem: 2551M
# [02/09 08:48:30 d2.utils.events]:  eta: 1:53:20  iter: 839  total_loss: 0.7555  loss_cls: 0.2975  loss_box_reg: 0.4021  loss_rpn_cls: 0.01677  loss_rpn_loc: 0.04568    time: 0.2736  last_time: 0.2837  data_time: 0.0061  last_data_time: 0.0060   lr: 0.0005  max_mem: 2551M
# [02/09 08:48:35 d2.utils.events]:  eta: 1:53:13  iter: 859  total_loss: 0.9156  loss_cls: 0.3559  loss_box_reg: 0.4665  loss_rpn_cls: 0.01783  loss_rpn_loc: 0.0551    time: 0.2735  last_time: 0.2855  data_time: 0.0059  last_data_time: 0.0066   lr: 0.0005  max_mem: 2551M
# [02/09 08:48:41 d2.utils.events]:  eta: 1:53:06  iter: 879  total_loss: 0.785  loss_cls: 0.3467  loss_box_reg: 0.3958  loss_rpn_cls: 0.02816  loss_rpn_loc: 0.04479    time: 0.2734  last_time: 0.2518  data_time: 0.0057  last_data_time: 0.0057   lr: 0.0005  max_mem: 2551M
# [02/09 08:48:46 d2.utils.events]:  eta: 1:52:59  iter: 899  total_loss: 0.7947  loss_cls: 0.3112  loss_box_reg: 0.4027  loss_rpn_cls: 0.01985  loss_rpn_loc: 0.03982    time: 0.2735  last_time: 0.2526  data_time: 0.0058  last_data_time: 0.0079   lr: 0.0005  max_mem: 2551M
# [02/09 08:48:52 d2.utils.events]:  eta: 1:52:51  iter: 919  total_loss: 0.8831  loss_cls: 0.2963  loss_box_reg: 0.4558  loss_rpn_cls: 0.01866  loss_rpn_loc: 0.06308    time: 0.2733  last_time: 0.2530  data_time: 0.0057  last_data_time: 0.0058   lr: 0.0005  max_mem: 2551M
# [02/09 08:48:57 d2.utils.events]:  eta: 1:52:46  iter: 939  total_loss: 0.8282  loss_cls: 0.341  loss_box_reg: 0.4198  loss_rpn_cls: 0.01293  loss_rpn_loc: 0.04326    time: 0.2734  last_time: 0.3105  data_time: 0.0062  last_data_time: 0.0068   lr: 0.0005  max_mem: 2551M
# [02/09 08:49:03 d2.utils.events]:  eta: 1:52:39  iter: 959  total_loss: 0.8879  loss_cls: 0.3444  loss_box_reg: 0.4486  loss_rpn_cls: 0.02128  loss_rpn_loc: 0.04843    time: 0.2734  last_time: 0.2838  data_time: 0.0061  last_data_time: 0.0057   lr: 0.0005  max_mem: 2551M
# [02/09 08:49:08 d2.utils.events]:  eta: 1:52:34  iter: 979  total_loss: 0.8121  loss_cls: 0.3176  loss_box_reg: 0.4173  loss_rpn_cls: 0.02188  loss_rpn_loc: 0.05195    time: 0.2735  last_time: 0.2837  data_time: 0.0059  last_data_time: 0.0052   lr: 0.0005  max_mem: 2551M
# [02/09 08:49:14 d2.utils.events]:  eta: 1:52:28  iter: 999  total_loss: 0.9121  loss_cls: 0.3618  loss_box_reg: 0.4474  loss_rpn_cls: 0.02156  loss_rpn_loc: 0.06791    time: 0.2735  last_time: 0.2830  data_time: 0.0055  last_data_time: 0.0049   lr: 0.0005  max_mem: 2551M
# [02/09 08:49:20 d2.utils.events]:  eta: 1:52:21  iter: 1019  total_loss: 0.8445  loss_cls: 0.3248  loss_box_reg: 0.4617  loss_rpn_cls: 0.02064  loss_rpn_loc: 0.0451    time: 0.2735  last_time: 0.2767  data_time: 0.0055  last_data_time: 0.0054   lr: 0.0005  max_mem: 2551M
# [02/09 08:49:25 d2.utils.events]:  eta: 1:52:13  iter: 1039  total_loss: 0.8643  loss_cls: 0.3464  loss_box_reg: 0.4744  loss_rpn_cls: 0.01694  loss_rpn_loc: 0.03076    time: 0.2736  last_time: 0.2611  data_time: 0.0057  last_data_time: 0.0042   lr: 0.0005  max_mem: 2551M
# [02/09 08:49:32 d2.utils.events]:  eta: 1:52:09  iter: 1059  total_loss: 0.9151  loss_cls: 0.3764  loss_box_reg: 0.4482  loss_rpn_cls: 0.02159  loss_rpn_loc: 0.04775    time: 0.2736  last_time: 0.2856  data_time: 0.0056  last_data_time: 0.0056   lr: 0.0005  max_mem: 2551M
# [02/09 08:49:37 d2.utils.events]:  eta: 1:52:02  iter: 1079  total_loss: 0.8849  loss_cls: 0.3618  loss_box_reg: 0.4518  loss_rpn_cls: 0.02046  loss_rpn_loc: 0.05701    time: 0.2735  last_time: 0.2812  data_time: 0.0059  last_data_time: 0.0051   lr: 0.0005  max_mem: 2551M
# [02/09 08:49:43 d2.utils.events]:  eta: 1:51:54  iter: 1099  total_loss: 0.8613  loss_cls: 0.3233  loss_box_reg: 0.4322  loss_rpn_cls: 0.01733  loss_rpn_loc: 0.05294    time: 0.2735  last_time: 0.2453  data_time: 0.0059  last_data_time: 0.0052   lr: 0.0005  max_mem: 2551M
# [02/09 08:49:48 d2.utils.events]:  eta: 1:51:50  iter: 1119  total_loss: 0.8507  loss_cls: 0.3049  loss_box_reg: 0.403  loss_rpn_cls: 0.01607  loss_rpn_loc: 0.03958    time: 0.2735  last_time: 0.2566  data_time: 0.0059  last_data_time: 0.0057   lr: 0.0005  max_mem: 2551M
# [02/09 08:49:54 d2.utils.events]:  eta: 1:51:43  iter: 1139  total_loss: 1.027  loss_cls: 0.3876  loss_box_reg: 0.4368  loss_rpn_cls: 0.02263  loss_rpn_loc: 0.08788    time: 0.2734  last_time: 0.2873  data_time: 0.0057  last_data_time: 0.0060   lr: 0.0005  max_mem: 2551M
# [02/09 08:49:59 d2.utils.events]:  eta: 1:51:38  iter: 1159  total_loss: 0.8742  loss_cls: 0.3505  loss_box_reg: 0.4307  loss_rpn_cls: 0.01797  loss_rpn_loc: 0.05697    time: 0.2735  last_time: 0.2753  data_time: 0.0062  last_data_time: 0.0056   lr: 0.0005  max_mem: 2551M
# [02/09 08:50:05 d2.utils.events]:  eta: 1:51:33  iter: 1179  total_loss: 0.8807  loss_cls: 0.3218  loss_box_reg: 0.4298  loss_rpn_cls: 0.02244  loss_rpn_loc: 0.06497    time: 0.2736  last_time: 0.2860  data_time: 0.0060  last_data_time: 0.0055   lr: 0.0005  max_mem: 2551M
# [02/09 08:50:10 d2.utils.events]:  eta: 1:51:26  iter: 1199  total_loss: 0.7087  loss_cls: 0.2907  loss_box_reg: 0.4069  loss_rpn_cls: 0.01688  loss_rpn_loc: 0.05627    time: 0.2736  last_time: 0.2845  data_time: 0.0058  last_data_time: 0.0061   lr: 0.0005  max_mem: 2551M
# [02/09 08:50:16 d2.utils.events]:  eta: 1:51:21  iter: 1219  total_loss: 0.7515  loss_cls: 0.2573  loss_box_reg: 0.4079  loss_rpn_cls: 0.01906  loss_rpn_loc: 0.0336    time: 0.2736  last_time: 0.2822  data_time: 0.0058  last_data_time: 0.0072   lr: 0.0005  max_mem: 2551M
# [02/09 08:50:21 d2.utils.events]:  eta: 1:51:14  iter: 1239  total_loss: 0.8657  loss_cls: 0.3394  loss_box_reg: 0.4615  loss_rpn_cls: 0.02734  loss_rpn_loc: 0.03192    time: 0.2735  last_time: 0.2896  data_time: 0.0062  last_data_time: 0.0078   lr: 0.0005  max_mem: 2551M
# [02/09 08:50:27 d2.utils.events]:  eta: 1:51:10  iter: 1259  total_loss: 0.8182  loss_cls: 0.3361  loss_box_reg: 0.3932  loss_rpn_cls: 0.02105  loss_rpn_loc: 0.03554    time: 0.2735  last_time: 0.2880  data_time: 0.0058  last_data_time: 0.0059   lr: 0.0005  max_mem: 2551M
# [02/09 08:50:32 d2.utils.events]:  eta: 1:51:04  iter: 1279  total_loss: 0.9459  loss_cls: 0.365  loss_box_reg: 0.4836  loss_rpn_cls: 0.02075  loss_rpn_loc: 0.06757    time: 0.2736  last_time: 0.2928  data_time: 0.0060  last_data_time: 0.0091   lr: 0.0005  max_mem: 2551M
# [02/09 08:50:38 d2.utils.events]:  eta: 1:51:01  iter: 1299  total_loss: 0.8908  loss_cls: 0.3069  loss_box_reg: 0.4489  loss_rpn_cls: 0.0197  loss_rpn_loc: 0.04867    time: 0.2737  last_time: 0.2804  data_time: 0.0059  last_data_time: 0.0055   lr: 0.0005  max_mem: 2551M
# [02/09 08:50:43 d2.utils.events]:  eta: 1:50:58  iter: 1319  total_loss: 0.8558  loss_cls: 0.3316  loss_box_reg: 0.3898  loss_rpn_cls: 0.01489  loss_rpn_loc: 0.04911    time: 0.2738  last_time: 0.2899  data_time: 0.0061  last_data_time: 0.0064   lr: 0.0005  max_mem: 2551M
# [02/09 08:50:49 d2.utils.events]:  eta: 1:50:54  iter: 1339  total_loss: 0.7745  loss_cls: 0.2848  loss_box_reg: 0.4306  loss_rpn_cls: 0.01805  loss_rpn_loc: 0.04267    time: 0.2738  last_time: 0.2360  data_time: 0.0057  last_data_time: 0.0052   lr: 0.0005  max_mem: 2551M
# [02/09 08:50:54 d2.utils.events]:  eta: 1:50:45  iter: 1359  total_loss: 1.065  loss_cls: 0.3579  loss_box_reg: 0.5005  loss_rpn_cls: 0.03282  loss_rpn_loc: 0.05248    time: 0.2736  last_time: 0.2895  data_time: 0.0059  last_data_time: 0.0061   lr: 0.0005  max_mem: 2551M
# [02/09 08:50:59 d2.utils.events]:  eta: 1:50:40  iter: 1379  total_loss: 0.8497  loss_cls: 0.3185  loss_box_reg: 0.4534  loss_rpn_cls: 0.01213  loss_rpn_loc: 0.03856    time: 0.2735  last_time: 0.2485  data_time: 0.0056  last_data_time: 0.0057   lr: 0.0005  max_mem: 2551M
# [02/09 08:51:05 d2.utils.events]:  eta: 1:50:36  iter: 1399  total_loss: 0.9071  loss_cls: 0.3624  loss_box_reg: 0.4712  loss_rpn_cls: 0.01866  loss_rpn_loc: 0.04653    time: 0.2736  last_time: 0.2814  data_time: 0.0060  last_data_time: 0.0056   lr: 0.0005  max_mem: 2551M
# [02/09 08:51:11 d2.utils.events]:  eta: 1:50:31  iter: 1419  total_loss: 0.8016  loss_cls: 0.3297  loss_box_reg: 0.4072  loss_rpn_cls: 0.0172  loss_rpn_loc: 0.0528    time: 0.2736  last_time: 0.2867  data_time: 0.0058  last_data_time: 0.0056   lr: 0.0005  max_mem: 2551M
# [02/09 08:51:16 d2.utils.events]:  eta: 1:50:26  iter: 1439  total_loss: 0.8671  loss_cls: 0.3269  loss_box_reg: 0.4274  loss_rpn_cls: 0.02752  loss_rpn_loc: 0.06415    time: 0.2735  last_time: 0.2499  data_time: 0.0057  last_data_time: 0.0055   lr: 0.0005  max_mem: 2551M
# [02/09 08:51:21 d2.utils.events]:  eta: 1:50:23  iter: 1459  total_loss: 0.8801  loss_cls: 0.337  loss_box_reg: 0.453  loss_rpn_cls: 0.01843  loss_rpn_loc: 0.07048    time: 0.2736  last_time: 0.2785  data_time: 0.0056  last_data_time: 0.0070   lr: 0.0005  max_mem: 2551M
# [02/09 08:51:27 d2.utils.events]:  eta: 1:50:16  iter: 1479  total_loss: 0.8967  loss_cls: 0.337  loss_box_reg: 0.4608  loss_rpn_cls: 0.01786  loss_rpn_loc: 0.0699    time: 0.2736  last_time: 0.2363  data_time: 0.0060  last_data_time: 0.0061   lr: 0.0005  max_mem: 2551M
# [02/09 08:51:33 d2.utils.events]:  eta: 1:50:10  iter: 1499  total_loss: 0.8151  loss_cls: 0.3174  loss_box_reg: 0.415  loss_rpn_cls: 0.01647  loss_rpn_loc: 0.05334    time: 0.2736  last_time: 0.2894  data_time: 0.0062  last_data_time: 0.0066   lr: 0.0005  max_mem: 2551M
# [02/09 08:51:38 d2.utils.events]:  eta: 1:50:05  iter: 1519  total_loss: 0.9447  loss_cls: 0.3771  loss_box_reg: 0.4561  loss_rpn_cls: 0.02013  loss_rpn_loc: 0.04795    time: 0.2735  last_time: 0.2516  data_time: 0.0060  last_data_time: 0.0054   lr: 0.0005  max_mem: 2551M
# [02/09 08:51:44 d2.utils.events]:  eta: 1:50:00  iter: 1539  total_loss: 0.7844  loss_cls: 0.3055  loss_box_reg: 0.4321  loss_rpn_cls: 0.01505  loss_rpn_loc: 0.03444    time: 0.2735  last_time: 0.2412  data_time: 0.0057  last_data_time: 0.0061   lr: 0.0005  max_mem: 2551M
# [02/09 08:51:49 d2.utils.events]:  eta: 1:49:54  iter: 1559  total_loss: 0.8296  loss_cls: 0.3055  loss_box_reg: 0.4299  loss_rpn_cls: 0.01457  loss_rpn_loc: 0.0443    time: 0.2734  last_time: 0.2556  data_time: 0.0056  last_data_time: 0.0062   lr: 0.0005  max_mem: 2551M
# [02/09 08:51:55 d2.utils.events]:  eta: 1:49:48  iter: 1579  total_loss: 0.8116  loss_cls: 0.3179  loss_box_reg: 0.4226  loss_rpn_cls: 0.01751  loss_rpn_loc: 0.03541    time: 0.2735  last_time: 0.2847  data_time: 0.0058  last_data_time: 0.0056   lr: 0.0005  max_mem: 2551M
# [02/09 08:52:00 d2.utils.events]:  eta: 1:49:40  iter: 1599  total_loss: 0.8107  loss_cls: 0.312  loss_box_reg: 0.445  loss_rpn_cls: 0.01918  loss_rpn_loc: 0.03133    time: 0.2735  last_time: 0.2819  data_time: 0.0056  last_data_time: 0.0052   lr: 0.0005  max_mem: 2551M
# [02/09 08:52:06 d2.utils.events]:  eta: 1:49:36  iter: 1619  total_loss: 0.8668  loss_cls: 0.2929  loss_box_reg: 0.444  loss_rpn_cls: 0.01761  loss_rpn_loc: 0.05421    time: 0.2735  last_time: 0.2969  data_time: 0.0061  last_data_time: 0.0059   lr: 0.0005  max_mem: 2551M
# [02/09 08:52:11 d2.utils.events]:  eta: 1:49:32  iter: 1639  total_loss: 0.7538  loss_cls: 0.2835  loss_box_reg: 0.3622  loss_rpn_cls: 0.01707  loss_rpn_loc: 0.03916    time: 0.2736  last_time: 0.2502  data_time: 0.0066  last_data_time: 0.0057   lr: 0.0005  max_mem: 2551M
# [02/09 08:52:18 d2.utils.events]:  eta: 1:49:28  iter: 1659  total_loss: 0.7597  loss_cls: 0.266  loss_box_reg: 0.3851  loss_rpn_cls: 0.01474  loss_rpn_loc: 0.03969    time: 0.2736  last_time: 0.2878  data_time: 0.0057  last_data_time: 0.0057   lr: 0.0005  max_mem: 2551M
# [02/09 08:52:23 d2.utils.events]:  eta: 1:49:24  iter: 1679  total_loss: 0.7914  loss_cls: 0.3232  loss_box_reg: 0.4257  loss_rpn_cls: 0.01353  loss_rpn_loc: 0.05121    time: 0.2736  last_time: 0.2506  data_time: 0.0060  last_data_time: 0.0062   lr: 0.0005  max_mem: 2551M
# [02/09 08:52:29 d2.utils.events]:  eta: 1:49:18  iter: 1699  total_loss: 0.7821  loss_cls: 0.2753  loss_box_reg: 0.4677  loss_rpn_cls: 0.0164  loss_rpn_loc: 0.0423    time: 0.2736  last_time: 0.2833  data_time: 0.0057  last_data_time: 0.0059   lr: 0.0005  max_mem: 2551M
# [02/09 08:52:34 d2.utils.events]:  eta: 1:49:14  iter: 1719  total_loss: 0.8056  loss_cls: 0.3162  loss_box_reg: 0.4068  loss_rpn_cls: 0.009987  loss_rpn_loc: 0.05727    time: 0.2736  last_time: 0.2939  data_time: 0.0061  last_data_time: 0.0110   lr: 0.0005  max_mem: 2551M
# [02/09 08:52:40 d2.utils.events]:  eta: 1:49:08  iter: 1739  total_loss: 0.8249  loss_cls: 0.3162  loss_box_reg: 0.4001  loss_rpn_cls: 0.01235  loss_rpn_loc: 0.04877    time: 0.2736  last_time: 0.2737  data_time: 0.0058  last_data_time: 0.0088   lr: 0.0005  max_mem: 2551M
# [02/09 08:52:45 d2.utils.events]:  eta: 1:49:01  iter: 1759  total_loss: 0.7959  loss_cls: 0.2919  loss_box_reg: 0.4097  loss_rpn_cls: 0.01612  loss_rpn_loc: 0.05073    time: 0.2735  last_time: 0.2858  data_time: 0.0058  last_data_time: 0.0058   lr: 0.0005  max_mem: 2551M
# [02/09 08:52:51 d2.utils.events]:  eta: 1:48:55  iter: 1779  total_loss: 0.7507  loss_cls: 0.2628  loss_box_reg: 0.3656  loss_rpn_cls: 0.01402  loss_rpn_loc: 0.0391    time: 0.2736  last_time: 0.2854  data_time: 0.0059  last_data_time: 0.0058   lr: 0.0005  max_mem: 2551M
# [02/09 08:52:56 d2.utils.events]:  eta: 1:48:52  iter: 1799  total_loss: 0.7595  loss_cls: 0.2844  loss_box_reg: 0.3849  loss_rpn_cls: 0.01374  loss_rpn_loc: 0.05979    time: 0.2737  last_time: 0.2797  data_time: 0.0061  last_data_time: 0.0052   lr: 0.0005  max_mem: 2551M
# [02/09 08:53:02 d2.utils.events]:  eta: 1:48:44  iter: 1819  total_loss: 0.9574  loss_cls: 0.3185  loss_box_reg: 0.4658  loss_rpn_cls: 0.02338  loss_rpn_loc: 0.06241    time: 0.2737  last_time: 0.2782  data_time: 0.0057  last_data_time: 0.0050   lr: 0.0005  max_mem: 2551M
# [02/09 08:53:07 d2.utils.events]:  eta: 1:48:38  iter: 1839  total_loss: 0.7501  loss_cls: 0.2905  loss_box_reg: 0.3914  loss_rpn_cls: 0.01468  loss_rpn_loc: 0.03624    time: 0.2737  last_time: 0.2873  data_time: 0.0058  last_data_time: 0.0060   lr: 0.0005  max_mem: 2551M
# [02/09 08:53:13 d2.utils.events]:  eta: 1:48:34  iter: 1859  total_loss: 0.9403  loss_cls: 0.3906  loss_box_reg: 0.4568  loss_rpn_cls: 0.01933  loss_rpn_loc: 0.0398    time: 0.2737  last_time: 0.2858  data_time: 0.0062  last_data_time: 0.0063   lr: 0.0005  max_mem: 2551M
# [02/09 08:53:18 d2.utils.events]:  eta: 1:48:32  iter: 1879  total_loss: 0.7647  loss_cls: 0.3042  loss_box_reg: 0.3938  loss_rpn_cls: 0.01427  loss_rpn_loc: 0.0433    time: 0.2737  last_time: 0.2857  data_time: 0.0060  last_data_time: 0.0063   lr: 0.0005  max_mem: 2551M
# [02/09 08:53:24 d2.utils.events]:  eta: 1:48:27  iter: 1899  total_loss: 0.7727  loss_cls: 0.3029  loss_box_reg: 0.3976  loss_rpn_cls: 0.01702  loss_rpn_loc: 0.06031    time: 0.2737  last_time: 0.2844  data_time: 0.0053  last_data_time: 0.0053   lr: 0.0005  max_mem: 2551M
# [02/09 08:53:30 d2.utils.events]:  eta: 1:48:26  iter: 1919  total_loss: 0.7799  loss_cls: 0.3089  loss_box_reg: 0.3918  loss_rpn_cls: 0.01718  loss_rpn_loc: 0.04068    time: 0.2737  last_time: 0.2892  data_time: 0.0059  last_data_time: 0.0060   lr: 0.0005  max_mem: 2551M
# [02/09 08:53:35 d2.utils.events]:  eta: 1:48:20  iter: 1939  total_loss: 0.7955  loss_cls: 0.3418  loss_box_reg: 0.4263  loss_rpn_cls: 0.01679  loss_rpn_loc: 0.0457    time: 0.2738  last_time: 0.2930  data_time: 0.0057  last_data_time: 0.0056   lr: 0.0005  max_mem: 2551M
# [02/09 08:53:41 d2.utils.events]:  eta: 1:48:15  iter: 1959  total_loss: 0.7309  loss_cls: 0.3003  loss_box_reg: 0.3723  loss_rpn_cls: 0.01332  loss_rpn_loc: 0.04801    time: 0.2738  last_time: 0.2819  data_time: 0.0064  last_data_time: 0.0056   lr: 0.0005  max_mem: 2551M
# [02/09 08:53:46 d2.utils.events]:  eta: 1:48:09  iter: 1979  total_loss: 0.6972  loss_cls: 0.271  loss_box_reg: 0.3694  loss_rpn_cls: 0.01677  loss_rpn_loc: 0.05854    time: 0.2738  last_time: 0.2846  data_time: 0.0061  last_data_time: 0.0051   lr: 0.0005  max_mem: 2551M
# [02/09 08:53:52 d2.utils.events]:  eta: 1:48:04  iter: 1999  total_loss: 0.8081  loss_cls: 0.3219  loss_box_reg: 0.3972  loss_rpn_cls: 0.01173  loss_rpn_loc: 0.0581    time: 0.2738  last_time: 0.2805  data_time: 0.0064  last_data_time: 0.0056   lr: 0.0005  max_mem: 2551M
# [02/09 08:53:58 d2.utils.events]:  eta: 1:47:59  iter: 2019  total_loss: 0.8229  loss_cls: 0.2749  loss_box_reg: 0.4546  loss_rpn_cls: 0.01528  loss_rpn_loc: 0.05866    time: 0.2739  last_time: 0.2839  data_time: 0.0058  last_data_time: 0.0059   lr: 0.0005  max_mem: 2551M
# [02/09 08:54:03 d2.utils.events]:  eta: 1:47:53  iter: 2039  total_loss: 0.7411  loss_cls: 0.2911  loss_box_reg: 0.3735  loss_rpn_cls: 0.0169  loss_rpn_loc: 0.03559    time: 0.2739  last_time: 0.2854  data_time: 0.0061  last_data_time: 0.0061   lr: 0.0005  max_mem: 2551M
# [02/09 08:54:09 d2.utils.events]:  eta: 1:47:48  iter: 2059  total_loss: 0.8061  loss_cls: 0.3031  loss_box_reg: 0.4429  loss_rpn_cls: 0.01471  loss_rpn_loc: 0.04548    time: 0.2739  last_time: 0.2873  data_time: 0.0058  last_data_time: 0.0064   lr: 0.0005  max_mem: 2551M
# [02/09 08:54:14 d2.utils.events]:  eta: 1:47:44  iter: 2079  total_loss: 0.9193  loss_cls: 0.3019  loss_box_reg: 0.4777  loss_rpn_cls: 0.02168  loss_rpn_loc: 0.05869    time: 0.2740  last_time: 0.2547  data_time: 0.0066  last_data_time: 0.0061   lr: 0.0005  max_mem: 2551M
# [02/09 08:54:20 d2.utils.events]:  eta: 1:47:38  iter: 2099  total_loss: 0.8649  loss_cls: 0.3036  loss_box_reg: 0.4519  loss_rpn_cls: 0.02255  loss_rpn_loc: 0.04104    time: 0.2740  last_time: 0.2889  data_time: 0.0061  last_data_time: 0.0056   lr: 0.0005  max_mem: 2551M
# [02/09 08:54:25 d2.utils.events]:  eta: 1:47:32  iter: 2119  total_loss: 0.8517  loss_cls: 0.3271  loss_box_reg: 0.417  loss_rpn_cls: 0.01875  loss_rpn_loc: 0.04468    time: 0.2740  last_time: 0.2937  data_time: 0.0059  last_data_time: 0.0049   lr: 0.0005  max_mem: 2551M
# [02/09 08:54:32 d2.utils.events]:  eta: 1:47:27  iter: 2139  total_loss: 0.767  loss_cls: 0.309  loss_box_reg: 0.3995  loss_rpn_cls: 0.02827  loss_rpn_loc: 0.07181    time: 0.2740  last_time: 0.2172  data_time: 0.0059  last_data_time: 0.0057   lr: 0.0005  max_mem: 2551M
# [02/09 08:54:38 d2.utils.events]:  eta: 1:47:23  iter: 2159  total_loss: 0.7378  loss_cls: 0.2941  loss_box_reg: 0.3893  loss_rpn_cls: 0.01709  loss_rpn_loc: 0.04184    time: 0.2739  last_time: 0.2876  data_time: 0.0060  last_data_time: 0.0054   lr: 0.0005  max_mem: 2551M
# [02/09 08:54:43 d2.utils.events]:  eta: 1:47:15  iter: 2179  total_loss: 0.8217  loss_cls: 0.3299  loss_box_reg: 0.3997  loss_rpn_cls: 0.02247  loss_rpn_loc: 0.05072    time: 0.2739  last_time: 0.2859  data_time: 0.0060  last_data_time: 0.0058   lr: 0.0005  max_mem: 2551M
# [02/09 08:54:49 d2.utils.events]:  eta: 1:47:10  iter: 2199  total_loss: 0.7096  loss_cls: 0.2648  loss_box_reg: 0.3792  loss_rpn_cls: 0.0185  loss_rpn_loc: 0.04712    time: 0.2739  last_time: 0.2773  data_time: 0.0062  last_data_time: 0.0076   lr: 0.0005  max_mem: 2551M
# [02/09 08:54:54 d2.utils.events]:  eta: 1:47:06  iter: 2219  total_loss: 0.823  loss_cls: 0.3545  loss_box_reg: 0.4203  loss_rpn_cls: 0.02235  loss_rpn_loc: 0.07961    time: 0.2740  last_time: 0.2889  data_time: 0.0063  last_data_time: 0.0062   lr: 0.0005  max_mem: 2551M
# [02/09 08:55:00 d2.utils.events]:  eta: 1:47:01  iter: 2239  total_loss: 0.7867  loss_cls: 0.2614  loss_box_reg: 0.4113  loss_rpn_cls: 0.01575  loss_rpn_loc: 0.0609    time: 0.2740  last_time: 0.2813  data_time: 0.0058  last_data_time: 0.0055   lr: 0.0005  max_mem: 2551M
# [02/09 08:55:05 d2.utils.events]:  eta: 1:46:57  iter: 2259  total_loss: 0.7412  loss_cls: 0.2818  loss_box_reg: 0.3771  loss_rpn_cls: 0.01786  loss_rpn_loc: 0.05169    time: 0.2740  last_time: 0.2612  data_time: 0.0061  last_data_time: 0.0064   lr: 0.0005  max_mem: 2551M
# [02/09 08:55:11 d2.utils.events]:  eta: 1:46:53  iter: 2279  total_loss: 0.6958  loss_cls: 0.2723  loss_box_reg: 0.3591  loss_rpn_cls: 0.01219  loss_rpn_loc: 0.04671    time: 0.2741  last_time: 0.2858  data_time: 0.0062  last_data_time: 0.0066   lr: 0.0005  max_mem: 2551M
# [02/09 08:55:16 d2.utils.events]:  eta: 1:46:47  iter: 2299  total_loss: 0.7556  loss_cls: 0.2694  loss_box_reg: 0.3916  loss_rpn_cls: 0.01962  loss_rpn_loc: 0.04169    time: 0.2741  last_time: 0.2525  data_time: 0.0066  last_data_time: 0.0078   lr: 0.0005  max_mem: 2551M
# [02/09 08:55:22 d2.utils.events]:  eta: 1:46:39  iter: 2319  total_loss: 0.6304  loss_cls: 0.2457  loss_box_reg: 0.3531  loss_rpn_cls: 0.0187  loss_rpn_loc: 0.03599    time: 0.2741  last_time: 0.2794  data_time: 0.0061  last_data_time: 0.0085   lr: 0.0005  max_mem: 2551M
# [02/09 08:55:27 d2.utils.events]:  eta: 1:46:30  iter: 2339  total_loss: 0.7888  loss_cls: 0.3072  loss_box_reg: 0.3875  loss_rpn_cls: 0.01311  loss_rpn_loc: 0.04309    time: 0.2740  last_time: 0.2196  data_time: 0.0064  last_data_time: 0.0067   lr: 0.0005  max_mem: 2551M
# [02/09 08:55:33 d2.utils.events]:  eta: 1:46:27  iter: 2359  total_loss: 0.8485  loss_cls: 0.3167  loss_box_reg: 0.4565  loss_rpn_cls: 0.01581  loss_rpn_loc: 0.04789    time: 0.2740  last_time: 0.2847  data_time: 0.0061  last_data_time: 0.0054   lr: 0.0005  max_mem: 2551M
# [02/09 08:55:38 d2.utils.events]:  eta: 1:46:20  iter: 2379  total_loss: 0.6182  loss_cls: 0.2398  loss_box_reg: 0.3093  loss_rpn_cls: 0.01312  loss_rpn_loc: 0.0376    time: 0.2740  last_time: 0.2473  data_time: 0.0057  last_data_time: 0.0054   lr: 0.0005  max_mem: 2551M
# ...
# [02/09 10:35:13 d2.utils.events]:  eta: 0:05:16  iter: 23879  total_loss: 0.6087  loss_cls: 0.1854  loss_box_reg: 0.3513  loss_rpn_cls: 0.00489  loss_rpn_loc: 0.03461    time: 0.2741  last_time: 0.2840  data_time: 0.0060  last_data_time: 0.0063   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:35:18 d2.utils.events]:  eta: 0:05:10  iter: 23899  total_loss: 0.6319  loss_cls: 0.1972  loss_box_reg: 0.3229  loss_rpn_cls: 0.006896  loss_rpn_loc: 0.05413    time: 0.2741  last_time: 0.2838  data_time: 0.0057  last_data_time: 0.0053   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:35:24 d2.utils.events]:  eta: 0:05:04  iter: 23919  total_loss: 0.6484  loss_cls: 0.2163  loss_box_reg: 0.3615  loss_rpn_cls: 0.01041  loss_rpn_loc: 0.05281    time: 0.2741  last_time: 0.2858  data_time: 0.0058  last_data_time: 0.0057   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:35:29 d2.utils.events]:  eta: 0:04:58  iter: 23939  total_loss: 0.6827  loss_cls: 0.2108  loss_box_reg: 0.3821  loss_rpn_cls: 0.01013  loss_rpn_loc: 0.05978    time: 0.2741  last_time: 0.2743  data_time: 0.0056  last_data_time: 0.0059   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:35:35 d2.utils.events]:  eta: 0:04:53  iter: 23959  total_loss: 0.6732  loss_cls: 0.2313  loss_box_reg: 0.3428  loss_rpn_cls: 0.01173  loss_rpn_loc: 0.0412    time: 0.2741  last_time: 0.2774  data_time: 0.0079  last_data_time: 0.0053   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:35:40 d2.utils.events]:  eta: 0:04:47  iter: 23979  total_loss: 0.6915  loss_cls: 0.2261  loss_box_reg: 0.3643  loss_rpn_cls: 0.01162  loss_rpn_loc: 0.05728    time: 0.2741  last_time: 0.2336  data_time: 0.0061  last_data_time: 0.0055   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:35:46 d2.utils.events]:  eta: 0:04:41  iter: 23999  total_loss: 0.6156  loss_cls: 0.2034  loss_box_reg: 0.3634  loss_rpn_cls: 0.006065  loss_rpn_loc: 0.05717    time: 0.2741  last_time: 0.2732  data_time: 0.0062  last_data_time: 0.0057   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:35:52 d2.utils.events]:  eta: 0:04:36  iter: 24019  total_loss: 0.6816  loss_cls: 0.2503  loss_box_reg: 0.3646  loss_rpn_cls: 0.01065  loss_rpn_loc: 0.06187    time: 0.2741  last_time: 0.2808  data_time: 0.0065  last_data_time: 0.0058   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:35:57 d2.utils.events]:  eta: 0:04:30  iter: 24039  total_loss: 0.549  loss_cls: 0.2077  loss_box_reg: 0.292  loss_rpn_cls: 0.007842  loss_rpn_loc: 0.04753    time: 0.2741  last_time: 0.2845  data_time: 0.0058  last_data_time: 0.0059   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:36:03 d2.utils.events]:  eta: 0:04:24  iter: 24059  total_loss: 0.535  loss_cls: 0.16  loss_box_reg: 0.3177  loss_rpn_cls: 0.007793  loss_rpn_loc: 0.03485    time: 0.2741  last_time: 0.2829  data_time: 0.0060  last_data_time: 0.0060   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:36:08 d2.utils.events]:  eta: 0:04:19  iter: 24079  total_loss: 0.5984  loss_cls: 0.2251  loss_box_reg: 0.3347  loss_rpn_cls: 0.007333  loss_rpn_loc: 0.04745    time: 0.2741  last_time: 0.2838  data_time: 0.0061  last_data_time: 0.0061   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:36:14 d2.utils.events]:  eta: 0:04:13  iter: 24099  total_loss: 0.5586  loss_cls: 0.176  loss_box_reg: 0.3672  loss_rpn_cls: 0.005059  loss_rpn_loc: 0.02738    time: 0.2741  last_time: 0.2637  data_time: 0.0057  last_data_time: 0.0033   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:36:19 d2.utils.events]:  eta: 0:04:07  iter: 24119  total_loss: 0.5822  loss_cls: 0.1717  loss_box_reg: 0.3141  loss_rpn_cls: 0.005558  loss_rpn_loc: 0.04236    time: 0.2741  last_time: 0.2875  data_time: 0.0058  last_data_time: 0.0057   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:36:25 d2.utils.events]:  eta: 0:04:02  iter: 24139  total_loss: 0.6124  loss_cls: 0.187  loss_box_reg: 0.3601  loss_rpn_cls: 0.007792  loss_rpn_loc: 0.03723    time: 0.2741  last_time: 0.2853  data_time: 0.0057  last_data_time: 0.0054   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:36:31 d2.utils.events]:  eta: 0:03:56  iter: 24159  total_loss: 0.5512  loss_cls: 0.2187  loss_box_reg: 0.2978  loss_rpn_cls: 0.006719  loss_rpn_loc: 0.04213    time: 0.2741  last_time: 0.2860  data_time: 0.0058  last_data_time: 0.0056   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:36:37 d2.utils.events]:  eta: 0:03:51  iter: 24179  total_loss: 0.4865  loss_cls: 0.1451  loss_box_reg: 0.2911  loss_rpn_cls: 0.006426  loss_rpn_loc: 0.03669    time: 0.2741  last_time: 0.2875  data_time: 0.0060  last_data_time: 0.0051   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:36:43 d2.utils.events]:  eta: 0:03:45  iter: 24199  total_loss: 0.634  loss_cls: 0.2018  loss_box_reg: 0.3352  loss_rpn_cls: 0.008288  loss_rpn_loc: 0.03669    time: 0.2741  last_time: 0.2733  data_time: 0.0059  last_data_time: 0.0049   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:36:48 d2.utils.events]:  eta: 0:03:39  iter: 24219  total_loss: 0.6132  loss_cls: 0.183  loss_box_reg: 0.3237  loss_rpn_cls: 0.009801  loss_rpn_loc: 0.03382    time: 0.2741  last_time: 0.2770  data_time: 0.0055  last_data_time: 0.0066   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:36:54 d2.utils.events]:  eta: 0:03:34  iter: 24239  total_loss: 0.668  loss_cls: 0.209  loss_box_reg: 0.3545  loss_rpn_cls: 0.008902  loss_rpn_loc: 0.05425    time: 0.2741  last_time: 0.2861  data_time: 0.0053  last_data_time: 0.0050   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:36:59 d2.utils.events]:  eta: 0:03:28  iter: 24259  total_loss: 0.503  loss_cls: 0.1495  loss_box_reg: 0.2862  loss_rpn_cls: 0.006961  loss_rpn_loc: 0.03467    time: 0.2741  last_time: 0.2482  data_time: 0.0063  last_data_time: 0.0059   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:37:05 d2.utils.events]:  eta: 0:03:23  iter: 24279  total_loss: 0.6505  loss_cls: 0.2262  loss_box_reg: 0.3484  loss_rpn_cls: 0.01398  loss_rpn_loc: 0.04398    time: 0.2741  last_time: 0.2915  data_time: 0.0058  last_data_time: 0.0065   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:37:10 d2.utils.events]:  eta: 0:03:17  iter: 24299  total_loss: 0.6011  loss_cls: 0.198  loss_box_reg: 0.2891  loss_rpn_cls: 0.008934  loss_rpn_loc: 0.03681    time: 0.2741  last_time: 0.2178  data_time: 0.0056  last_data_time: 0.0048   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:37:16 d2.utils.events]:  eta: 0:03:11  iter: 24319  total_loss: 0.6736  loss_cls: 0.2052  loss_box_reg: 0.3539  loss_rpn_cls: 0.008358  loss_rpn_loc: 0.05539    time: 0.2741  last_time: 0.2716  data_time: 0.0057  last_data_time: 0.0052   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:37:21 d2.utils.events]:  eta: 0:03:06  iter: 24339  total_loss: 0.5334  loss_cls: 0.1846  loss_box_reg: 0.3276  loss_rpn_cls: 0.007509  loss_rpn_loc: 0.04112    time: 0.2741  last_time: 0.2899  data_time: 0.0054  last_data_time: 0.0052   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:37:27 d2.utils.events]:  eta: 0:03:00  iter: 24359  total_loss: 0.5687  loss_cls: 0.1961  loss_box_reg: 0.3321  loss_rpn_cls: 0.008114  loss_rpn_loc: 0.0357    time: 0.2741  last_time: 0.2823  data_time: 0.0063  last_data_time: 0.0060   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:37:32 d2.utils.events]:  eta: 0:02:54  iter: 24379  total_loss: 0.5857  loss_cls: 0.1658  loss_box_reg: 0.3325  loss_rpn_cls: 0.006319  loss_rpn_loc: 0.03468    time: 0.2741  last_time: 0.2844  data_time: 0.0060  last_data_time: 0.0051   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:37:38 d2.utils.events]:  eta: 0:02:49  iter: 24399  total_loss: 0.5506  loss_cls: 0.1799  loss_box_reg: 0.3255  loss_rpn_cls: 0.008459  loss_rpn_loc: 0.05161    time: 0.2741  last_time: 0.2769  data_time: 0.0058  last_data_time: 0.0080   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:37:43 d2.utils.events]:  eta: 0:02:43  iter: 24419  total_loss: 0.6248  loss_cls: 0.2182  loss_box_reg: 0.3541  loss_rpn_cls: 0.007072  loss_rpn_loc: 0.04267    time: 0.2741  last_time: 0.2370  data_time: 0.0057  last_data_time: 0.0052   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:37:49 d2.utils.events]:  eta: 0:02:37  iter: 24439  total_loss: 0.6602  loss_cls: 0.1993  loss_box_reg: 0.3852  loss_rpn_cls: 0.01018  loss_rpn_loc: 0.04468    time: 0.2741  last_time: 0.2327  data_time: 0.0057  last_data_time: 0.0046   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:37:54 d2.utils.events]:  eta: 0:02:32  iter: 24459  total_loss: 0.5623  loss_cls: 0.1861  loss_box_reg: 0.3183  loss_rpn_cls: 0.01036  loss_rpn_loc: 0.05972    time: 0.2741  last_time: 0.2831  data_time: 0.0058  last_data_time: 0.0053   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:38:00 d2.utils.events]:  eta: 0:02:26  iter: 24479  total_loss: 0.5947  loss_cls: 0.1941  loss_box_reg: 0.3507  loss_rpn_cls: 0.007967  loss_rpn_loc: 0.05084    time: 0.2741  last_time: 0.2521  data_time: 0.0059  last_data_time: 0.0066   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:38:06 d2.utils.events]:  eta: 0:02:21  iter: 24499  total_loss: 0.5936  loss_cls: 0.1995  loss_box_reg: 0.3415  loss_rpn_cls: 0.005043  loss_rpn_loc: 0.03185    time: 0.2741  last_time: 0.2730  data_time: 0.0055  last_data_time: 0.0054   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:38:11 d2.utils.events]:  eta: 0:02:15  iter: 24519  total_loss: 0.6078  loss_cls: 0.2021  loss_box_reg: 0.3636  loss_rpn_cls: 0.01065  loss_rpn_loc: 0.04167    time: 0.2741  last_time: 0.2790  data_time: 0.0058  last_data_time: 0.0035   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:38:17 d2.utils.events]:  eta: 0:02:09  iter: 24539  total_loss: 0.5499  loss_cls: 0.1958  loss_box_reg: 0.3301  loss_rpn_cls: 0.008352  loss_rpn_loc: 0.02649    time: 0.2741  last_time: 0.2844  data_time: 0.0058  last_data_time: 0.0065   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:38:22 d2.utils.events]:  eta: 0:02:04  iter: 24559  total_loss: 0.5307  loss_cls: 0.1617  loss_box_reg: 0.2946  loss_rpn_cls: 0.008418  loss_rpn_loc: 0.03317    time: 0.2741  last_time: 0.2825  data_time: 0.0059  last_data_time: 0.0052   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:38:28 d2.utils.events]:  eta: 0:01:58  iter: 24579  total_loss: 0.4944  loss_cls: 0.1819  loss_box_reg: 0.2846  loss_rpn_cls: 0.00589  loss_rpn_loc: 0.0331    time: 0.2741  last_time: 0.2709  data_time: 0.0057  last_data_time: 0.0054   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:38:33 d2.utils.events]:  eta: 0:01:52  iter: 24599  total_loss: 0.6005  loss_cls: 0.1914  loss_box_reg: 0.3264  loss_rpn_cls: 0.007044  loss_rpn_loc: 0.04576    time: 0.2741  last_time: 0.2907  data_time: 0.0058  last_data_time: 0.0103   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:38:39 d2.utils.events]:  eta: 0:01:47  iter: 24619  total_loss: 0.5362  loss_cls: 0.169  loss_box_reg: 0.3231  loss_rpn_cls: 0.01122  loss_rpn_loc: 0.02573    time: 0.2741  last_time: 0.2971  data_time: 0.0059  last_data_time: 0.0063   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:38:45 d2.utils.events]:  eta: 0:01:41  iter: 24639  total_loss: 0.5872  loss_cls: 0.1906  loss_box_reg: 0.3438  loss_rpn_cls: 0.006438  loss_rpn_loc: 0.0424    time: 0.2741  last_time: 0.2275  data_time: 0.0055  last_data_time: 0.0047   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:38:51 d2.utils.events]:  eta: 0:01:35  iter: 24659  total_loss: 0.5337  loss_cls: 0.1788  loss_box_reg: 0.3014  loss_rpn_cls: 0.01043  loss_rpn_loc: 0.03168    time: 0.2741  last_time: 0.2827  data_time: 0.0055  last_data_time: 0.0060   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:38:56 d2.utils.events]:  eta: 0:01:30  iter: 24679  total_loss: 0.5474  loss_cls: 0.1758  loss_box_reg: 0.327  loss_rpn_cls: 0.009331  loss_rpn_loc: 0.05156    time: 0.2741  last_time: 0.2484  data_time: 0.0057  last_data_time: 0.0052   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:39:02 d2.utils.events]:  eta: 0:01:24  iter: 24699  total_loss: 0.652  loss_cls: 0.2272  loss_box_reg: 0.3529  loss_rpn_cls: 0.01665  loss_rpn_loc: 0.04784    time: 0.2741  last_time: 0.2850  data_time: 0.0057  last_data_time: 0.0091   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:39:07 d2.utils.events]:  eta: 0:01:18  iter: 24719  total_loss: 0.6075  loss_cls: 0.2062  loss_box_reg: 0.3341  loss_rpn_cls: 0.01004  loss_rpn_loc: 0.03572    time: 0.2741  last_time: 0.2768  data_time: 0.0056  last_data_time: 0.0058   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:39:13 d2.utils.events]:  eta: 0:01:13  iter: 24739  total_loss: 0.4769  loss_cls: 0.1413  loss_box_reg: 0.265  loss_rpn_cls: 0.00913  loss_rpn_loc: 0.03593    time: 0.2741  last_time: 0.2802  data_time: 0.0061  last_data_time: 0.0053   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:39:18 d2.utils.events]:  eta: 0:01:07  iter: 24759  total_loss: 0.6842  loss_cls: 0.2502  loss_box_reg: 0.3562  loss_rpn_cls: 0.01171  loss_rpn_loc: 0.04166    time: 0.2741  last_time: 0.2856  data_time: 0.0057  last_data_time: 0.0063   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:39:23 d2.utils.events]:  eta: 0:01:01  iter: 24779  total_loss: 0.5831  loss_cls: 0.2152  loss_box_reg: 0.3471  loss_rpn_cls: 0.007722  loss_rpn_loc: 0.03402    time: 0.2741  last_time: 0.2746  data_time: 0.0059  last_data_time: 0.0052   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:39:29 d2.utils.events]:  eta: 0:00:56  iter: 24799  total_loss: 0.569  loss_cls: 0.1859  loss_box_reg: 0.3336  loss_rpn_cls: 0.01148  loss_rpn_loc: 0.04455    time: 0.2741  last_time: 0.2820  data_time: 0.0058  last_data_time: 0.0061   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:39:34 d2.utils.events]:  eta: 0:00:50  iter: 24819  total_loss: 0.5783  loss_cls: 0.2043  loss_box_reg: 0.3243  loss_rpn_cls: 0.00663  loss_rpn_loc: 0.02979    time: 0.2741  last_time: 0.2813  data_time: 0.0057  last_data_time: 0.0052   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:39:40 d2.utils.events]:  eta: 0:00:45  iter: 24839  total_loss: 0.608  loss_cls: 0.1978  loss_box_reg: 0.303  loss_rpn_cls: 0.009158  loss_rpn_loc: 0.04607    time: 0.2741  last_time: 0.2832  data_time: 0.0059  last_data_time: 0.0051   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:39:45 d2.utils.events]:  eta: 0:00:39  iter: 24859  total_loss: 0.563  loss_cls: 0.1833  loss_box_reg: 0.3428  loss_rpn_cls: 0.008054  loss_rpn_loc: 0.04131    time: 0.2741  last_time: 0.2823  data_time: 0.0057  last_data_time: 0.0040   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:39:50 d2.utils.events]:  eta: 0:00:33  iter: 24879  total_loss: 0.6558  loss_cls: 0.1988  loss_box_reg: 0.3355  loss_rpn_cls: 0.00813  loss_rpn_loc: 0.07732    time: 0.2741  last_time: 0.2772  data_time: 0.0054  last_data_time: 0.0084   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:39:56 d2.utils.events]:  eta: 0:00:28  iter: 24899  total_loss: 0.5692  loss_cls: 0.1896  loss_box_reg: 0.3035  loss_rpn_cls: 0.0102  loss_rpn_loc: 0.0334    time: 0.2741  last_time: 0.2488  data_time: 0.0058  last_data_time: 0.0058   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:40:01 d2.utils.events]:  eta: 0:00:22  iter: 24919  total_loss: 0.5702  loss_cls: 0.1898  loss_box_reg: 0.3115  loss_rpn_cls: 0.008661  loss_rpn_loc: 0.04562    time: 0.2741  last_time: 0.2917  data_time: 0.0057  last_data_time: 0.0050   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:40:07 d2.utils.events]:  eta: 0:00:16  iter: 24939  total_loss: 0.6977  loss_cls: 0.2307  loss_box_reg: 0.3578  loss_rpn_cls: 0.01247  loss_rpn_loc: 0.04603    time: 0.2741  last_time: 0.2841  data_time: 0.0059  last_data_time: 0.0056   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:40:13 d2.utils.events]:  eta: 0:00:11  iter: 24959  total_loss: 0.5985  loss_cls: 0.2033  loss_box_reg: 0.3574  loss_rpn_cls: 0.006128  loss_rpn_loc: 0.03569    time: 0.2741  last_time: 0.2749  data_time: 0.0055  last_data_time: 0.0054   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:40:18 d2.utils.events]:  eta: 0:00:05  iter: 24979  total_loss: 0.6167  loss_cls: 0.2061  loss_box_reg: 0.3301  loss_rpn_cls: 0.0071  loss_rpn_loc: 0.03304    time: 0.2741  last_time: 0.2853  data_time: 0.0059  last_data_time: 0.0058   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:40:25 d2.utils.events]:  eta: 0:00:00  iter: 24999  total_loss: 0.5418  loss_cls: 0.1791  loss_box_reg: 0.3038  loss_rpn_cls: 0.008071  loss_rpn_loc: 0.0462    time: 0.2741  last_time: 0.2884  data_time: 0.0060  last_data_time: 0.0061   lr: 2.5e-05  max_mem: 2553M
# [02/09 10:40:25 d2.engine.hooks]: Overall training speed: 24998 iterations in 1:54:11 (0.2741 s / it)
# [02/09 10:40:25 d2.engine.hooks]: Total training time: 1:55:56 (0:01:44 on hooks)
# 6960.357439041138

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.DEVICE = 'cuda' # cuda
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 13
cfg.MODEL.WEIGHTS = "/kaggle/working/output/model_final.pth"
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7   # set the testing threshold for this model
predictor = DefaultPredictor(cfg)

im = cv2.imread("/kaggle/input/dl-enigma-10-sust-cse-carnival-2024/dlenigma1/BadODD/images/test/chittagong_bohoddarhat1_1003.jpg")
outputs = predictor(im)
v = Visualizer(im, scale=1., instance_mode =  ColorMode.IMAGE    )

v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
img = v.get_image()[:,:,[2,1,0]]
img = Image.fromarray(img)
plt.figure(figsize=(10, 10))
plt.imshow(img)
# Out:
# [02/09 10:40:26 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /kaggle/working/output/model_final.pth ...

# %%
def get_prediction_string(boxes, scores, classes,height1, width1):
    pred_strs = []
    for i, score in enumerate(scores):
        single_pred_str = ""
        single_pred_str += str(float(classes[i])) + " " + str(float(score)) + " "
        #print(boxes[i])
        x_center , y_center, width,height = boxes[i]
        x1 = ((float(x_center) + float(width))/2)/float(width1)
        y1 = ((float(y_center) + float(height))/2)/float(height1)
        
        width = (-float(x_center) + float(width))/float(width1)
        height = (-float(y_center) + float(height))/float(height1)
        x2=float(x1)-(float(width)/2)
        y2=float(y1)-(float(height)/2)
        #single_pred_str += " ".join(str(float(x)) for x in boxes[i])
        single_pred_str +=  f"{x2} {y2} {width} {height}"
        
        pred_strs.append(single_pred_str)
    ans = ','.join(map(str, pred_strs))
    if len(ans):
        return ans
#     the solution metrics faield in case of a NaN, '' (empty). So, return "0 0 0 0 0 0" for NaN, '' (empty) string
    return "0 0 0 0 0 0"

# get the predcition in id, ImageID, PredictionString_pred foramt ...

def get_prediction_entry(i, filename, boxes, scores, classes,height1, width1):
    return {
        "id": i, # strating from 0 ...
        "ImageID": filename.split('.')[0], # before the extension ...
        "PredictionString_pred": get_prediction_string(boxes, scores, classes,height1, width1)
    }

# Directory path ...
test_directory = "/kaggle/input/dl-enigma-10-sust-cse-carnival-2024/dlenigma1/BadODD/images/test"
#test_directory = "/kaggle/input/image-test"
# Load the model ...
#model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt')

# do the inference ...

def predict_all_files(test_directory):
    predictions = []
    for i,filename in tqdm(enumerate(os.listdir(test_directory))):
        if filename.endswith(".jpg"):
            filepath = os.path.join(test_directory, filename)
            im = cv2.imread(filepath)
            height1, width1, _ = im.shape
            
            #print(im.shape)
            results = predictor(im)
            instances = results["instances"]
            boxes_cpu = instances.pred_boxes.tensor.cpu()
            scores_cpu = instances.scores.cpu()
            classes_cpu = instances.pred_classes.cpu()

                   # Convert CPU tensors to NumPy arrays
            boxes = boxes_cpu.numpy()  # Extract bounding boxes as a numpy array
            scores = scores_cpu.numpy()  # Extract prediction scores as a numpy array
            classes = classes_cpu.numpy()
            prediction = get_prediction_entry(i, filename, boxes, scores, classes,height1, width1)
            predictions.append(prediction)
            #print(predictions[0])
            
#             to csv format ...
    predictions_df = pd.DataFrame(predictions)
    predictions_df.to_csv("submission.csv", index=False)

# call the inference function ...
predict_all_files(test_directory)
# Out:
# 1964it [04:17,  7.62it/s]
